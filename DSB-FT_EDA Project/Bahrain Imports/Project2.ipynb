# %%
# Dowland the liabries we need them in the project
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
#read csv file
df=pd.read_csv('./')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 2
#       1 #read csv file
# ----> 2 df=pd.read_csv('2021.csv')
#       3 df=pd.read_csv('./2022.csv')
#       4 df=pd.read_csv('./2023.csv')
#       5 df=pd.read_csv('./2024.csv')
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
#see the columns and types
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 324818 entries, 0 to 324817
# Data columns (total 14 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ﻿N                    324818 non-null  int64
#  1   Year                  324818 non-null  int64
#  2   Month                 324818 non-null  str
#  3   Commodity No          324818 non-null  int64
#  4   Commodity             324818 non-null  str
#  5   السلعة                324818 non-null  str
#  6   UN code               324759 non-null  str
#  7   Country Name          324818 non-null  str
#  8   الدولة                324818 non-null  str
#  9   Import Value (BD)     324818 non-null  float64
#  10  Import Value (USA $)  324818 non-null  float64
#  11  Import Weight (KG)    324818 non-null  float64
#  12  Import Quantity       324818 non-null  float64
#  13  UM                    324818 non-null  str
# dtypes: float64(4), int64(3), str(7)
# memory usage: 86.8 MB

# %%
#see the data and read them
df.head()
# Out:
#    ﻿N  Year       Month  Commodity No         Commodity  \
# 0   1  2025  01 January       1012910  HORSES FOR SPORT
# 1   2  2025  01 January       1012990      Other HORSES
# 2   3  2025  01 January       1022900      OTHER BOVINE
# 3   4  2025  01 January       1041090       OTHER SHEEP
# 4   5  2025  01 January       1041090       OTHER SHEEP
#
#                        السلعة UN code    Country Name  \
# 0                خيول للرياضة      GB  UNITED KINGDOM
# 1           غيرها من خيول آخر      HU         HUNGARY
# 2              غيرها من ابقار      SO         SOMALIA
# 3  حيوانات من فصيلة الضان اخر      IR            IRAN
# 4  حيوانات من فصيلة الضان اخر      SO         SOMALIA
#
#                     الدولة  Import Value (BD)  Import Value (USA $)  \
# 0          المملكة المتحدة            408.846           1087.356383
# 1                  هنغاريا            374.229            995.289894
# 2                  الصومال         155793.354         414344.026600
# ...

# %%
#drop the columns we do not need them (the duplicated)
df1 = df.drop(columns=['السلعة', 'الدولة'])
df1
# Out:
#             ﻿N  Year        Month  Commodity No  \
# 0            1  2025   01 January       1012910
# 1            2  2025   01 January       1012990
# 2            3  2025   01 January       1022900
# 3            4  2025   01 January       1041090
# 4            5  2025   01 January       1041090
# ...        ...   ...          ...           ...
# 324813  324814  2025  12 December      98010000
# 324814  324815  2025  12 December      98010000
# 324815  324816  2025  12 December      98010000
# 324816  324817  2025  12 December      98010000
# 324817  324818  2025  12 December      98980000
#
#                                                 Commodity UN code  \
# 0                                        HORSES FOR SPORT      GB
# 1                                            Other HORSES      HU
# 2                                            OTHER BOVINE      SO
# 3                                             OTHER SHEEP      IR
# ...

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 324818 entries, 0 to 324817
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ﻿N                    324818 non-null  int64
#  1   Year                  324818 non-null  int64
#  2   Month                 324818 non-null  str
#  3   Commodity No          324818 non-null  int64
#  4   Commodity             324818 non-null  str
#  5   UN code               324759 non-null  str
#  6   Country Name          324818 non-null  str
#  7   Import Value (BD)     324818 non-null  float64
#  8   Import Value (USA $)  324818 non-null  float64
#  9   Import Weight (KG)    324818 non-null  float64
#  10  Import Quantity       324818 non-null  float64
#  11  UM                    324818 non-null  str
# dtypes: float64(4), int64(3), str(5)
# memory usage: 50.0 MB

# %%
#change the quantity to be integer
